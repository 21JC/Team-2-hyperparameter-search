# %%
import pandas as pd
import json

# %%
Trail = pd.read_csv('hyperparameter_data.csv')

# %%
import ast

# %%
Trail['hyperparameters'].apply(lambda x: ast.literal_eval(x))
# Out:
# 0       {'base_score': 0.5, 'monotone_constraints': '(...
# 1       {'monotone_constraints': '(0)', 'max_depth': 1...
# 2       {'tree_method': 'auto', 'l2_regularization': 1...
# 3       {'base_score': 0.5, 'column_sample_by_tree': 1...
# 4       {'column_sample_by_tree': 1.0, 'monotone_const...
#                               ...
# 3720    {'max_count': 348, 'min_child_weight': 68, 'l2...
# 3721    {'column_sample_by_tree': 1.0, 'max_count': 33...
# 3722    {'monotone_constraints': '(0)', 'learn_rate': ...
# 3723    {'monotone_constraints': '(0)', 'subsample_rat...
# 3724    {'column_sample_by_level': 1.0, 'monotone_cons...
# Name: hyperparameters, Length: 3725, dtype: object

# %%
Trail['hyperparameters'] = Trail['hyperparameters'].apply(lambda x: ast.literal_eval(x))

# %%
pd.DataFrame(list(Trail['hyperparameters'].values))
# Out:
#       base_score monotone_constraints  column_sample_by_tree  \
# 0            0.5                  (0)                    1.0
# 1            0.5                  (0)                    1.0
# 2            0.5                  (0)                    1.0
# 3            0.5                  (0)                    1.0
# 4            0.5                  (0)                    1.0
# ...          ...                  ...                    ...
# 3720         0.5                  (0)                    1.0
# 3721         0.5                  (0)                    1.0
# 3722         0.5                  (0)                    1.0
# 3723         0.5                  (0)                    1.0
# 3724         0.5                  (0)                    1.0
#
#       column_sample_by_level tree_method  subsample_ratio  max_count  \
# 0                        1.0        auto              1.0        168
# 1                        1.0        auto              1.0        160
# 2                        1.0        auto              1.0        366
# 3                        1.0        auto              1.0        323
# 4                        1.0        auto              1.0        274
# ...                      ...         ...              ...        ...
# 3720                     1.0        auto              1.0        348
# 3721                     1.0        auto              1.0        338
# 3722                     1.0        auto              1.0        137
# 3723                     1.0        auto              1.0        348
# 3724                     1.0        auto              1.0        338
#
#       l2_regularization  learn_rate  max_depth  min_child_weight  loss  \
# 0                   1.0    0.077407         10                63   NaN
# 1                   1.0    0.061635         11                37   NaN
# 2                   1.0    0.071619         11                44   NaN
# 3                   1.0    0.050162         11                61  none
# 4                   1.0    0.098661         12                51   NaN
# ...                 ...         ...        ...               ...   ...
# 3720                1.0    0.081830         11                68   NaN
# 3721                1.0    0.074883         10                35   NaN
# 3722                1.0    0.054669         11                57   NaN
# 3723                1.0    0.061291         11                32   NaN
# 3724                1.0    0.061523         11                69   NaN
#
#       maxCategories
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 3720            NaN
# 3721            NaN
# 3722            NaN
# 3723           -2.0
# 3724            NaN
#
# [3725 rows x 13 columns]

# %%
hyperparameter = pd.concat([Trail,pd.DataFrame(list(Trail['hyperparameters'].values))],axis=1 )

# %%
hyperparameter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3725 entries, 0 to 3724
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              3725 non-null   int64
#  1   hyperparameters         3725 non-null   object
#  2   trial_id                3725 non-null   object
#  3   parent_study_id         3725 non-null   object
#  4   base_score              3725 non-null   float64
#  5   monotone_constraints    3725 non-null   object
#  6   column_sample_by_tree   3725 non-null   float64
#  7   column_sample_by_level  3725 non-null   float64
#  8   tree_method             3725 non-null   object
#  9   subsample_ratio         3725 non-null   float64
#  10  max_count               3725 non-null   int64
#  11  l2_regularization       3725 non-null   float64
#  12  learn_rate              3725 non-null   float64
#  13  max_depth               3725 non-null   int64
#  14  min_child_weight        3725 non-null   int64
#  15  loss                    300 non-null    object
#  16  maxCategories           249 non-null    float64
# dtypes: float64(7), int64(4), object(6)
# memory usage: 494.9+ KB

# %%
hyperparameter['trial_id'][0]
# Out:
# 'model_20211021-140355-3d2e0e259d-63c4e8d218'

# %%
pd.read_csv(r'C:\Users\cheng\Desktop\235\data\learning_summaries\model_20210812-213541-fca9797c32-54d221a196_model_20210812-213541-fca9797c32.csv')
# Out:
#      Unnamed: 0  train_summaries  test_summaries  \
# 0             0       610.553528      634.190674
# 1             1       575.832214      600.482666
# 2             2       543.291260      568.872192
# 3             3       512.808044      539.260071
# 4             4       484.260498      511.521454
# ..          ...              ...             ...
# 268         268       110.269661      131.511078
# 269         269       110.246490      131.503250
# 270         270       110.219116      131.492676
# 271         271       110.196045      131.487015
# 272         272       110.174530      131.477737
#
#                                         trial_id  \
# 0    model_20210812-213541-fca9797c32-54d221a196
# 1    model_20210812-213541-fca9797c32-54d221a196
# 2    model_20210812-213541-fca9797c32-54d221a196
# 3    model_20210812-213541-fca9797c32-54d221a196
# 4    model_20210812-213541-fca9797c32-54d221a196
# ..                                           ...
# 268  model_20210812-213541-fca9797c32-54d221a196
# 269  model_20210812-213541-fca9797c32-54d221a196
# 270  model_20210812-213541-fca9797c32-54d221a196
# 271  model_20210812-213541-fca9797c32-54d221a196
# 272  model_20210812-213541-fca9797c32-54d221a196
#
#                       parent_study_id
# 0    model_20210812-213541-fca9797c32
# 1    model_20210812-213541-fca9797c32
# 2    model_20210812-213541-fca9797c32
# 3    model_20210812-213541-fca9797c32
# 4    model_20210812-213541-fca9797c32
# ..                                ...
# 268  model_20210812-213541-fca9797c32
# 269  model_20210812-213541-fca9797c32
# 270  model_20210812-213541-fca9797c32
# 271  model_20210812-213541-fca9797c32
# 272  model_20210812-213541-fca9797c32
#
# [273 rows x 5 columns]
